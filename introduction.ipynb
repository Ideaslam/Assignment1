# %% [markdown]
# <a href="https://colab.research.google.com/github/Ideaslam/Assignment1/blob/master/introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
import numpy as np
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %%
celsius_q    = np.array([-40, -10,  0,  8, 15, 22,  38],  dtype=float)
fahrenheit_a = np.array([-40,  14, 32, 46, 59, 72, 100],  dtype=float)

for i,c in enumerate(celsius_q):
  print("{} degrees Celsius = {} degrees Fahrenheit".format(c, fahrenheit_a[i]))
# Out:
# -40.0 degrees Celsius = -40.0 degrees Fahrenheit
# -10.0 degrees Celsius = 14.0 degrees Fahrenheit
# 0.0 degrees Celsius = 32.0 degrees Fahrenheit
# 8.0 degrees Celsius = 46.0 degrees Fahrenheit
# 15.0 degrees Celsius = 59.0 degrees Fahrenheit
# 22.0 degrees Celsius = 72.0 degrees Fahrenheit
# 38.0 degrees Celsius = 100.0 degrees Fahrenheit

# %%
l0 = tf.keras.layers.Dense(units=1 , input_shape=[1])

# %%
model=tf.keras.Sequential([l0])

# %%
model.compile(loss="mean_squared_error", optimizer=tf.keras.optimizers.Adam(0.1))

# %%
history = model.fit(celsius_q, fahrenheit_a,epochs=1000,verbose=False)
print("Finished training the model")
# Out:
# Finished training the model

# %%
print(history.history)
# Out:
# {'loss': [6708.91796875, 6347.39013671875, 5997.59033203125, 5659.70458984375, 5333.90966796875, 5020.35107421875, 4719.14990234375, 4430.408203125, 4154.1943359375, 3890.548583984375, 3639.481201171875, 3400.971435546875, 3174.966064453125, 2961.37646484375, 2760.08203125, 2570.927001953125, 2393.72119140625, 2228.240478515625, 2074.22705078125, 1931.3909912109375, 1799.4100341796875, 1677.931884765625, 1566.5767822265625, 1464.9381103515625, 1372.5865478515625, 1289.0716552734375, 1213.9254150390625, 1146.66552734375, 1086.7987060546875, 1033.824462890625, 987.2390747070312, 946.53857421875, 911.2234497070312, 880.8016967773438, 854.79296875, 832.7308959960938, 814.16748046875, 798.6748046875, 785.8478393554688, 775.3067626953125, 766.6984252929688, 759.6970825195312, 754.0059204101562, 749.3568115234375, 745.5110473632812, 742.2578125, 739.4142456054688, 736.8242797851562, 734.3566284179688, 731.9039306640625, 729.3802490234375, 726.7200927734375, 723.8754272460938, 720.8139038085
# ...

# %%
import matplotlib.pyplot as plt

plt.xlabel('Epoch Number')
plt.ylabel('Loss Magnitude')
plt.plot(history.history['loss'])

# %%
print(model.predict([100.0]))
# Out:
# 1/1 [==============================] - 0s 38ms/step
# [[211.7474]]

# %%
print(l0.get_weights())
# Out:
# [array([[1.7979494]], dtype=float32), array([31.952475], dtype=float32)]

# %%
l0 = tf.keras.layers.Dense(units=4, input_shape=[1])
l1 = tf.keras.layers.Dense(units=4)
l2 = tf.keras.layers.Dense(units=1)
model = tf.keras.Sequential([l0, l1, l2])
model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Lion(0.1))
model.fit(celsius_q, fahrenheit_a, epochs=500, verbose=False)
print("Finished training the model")
print(model.predict([100.0]))
print("Model predicts that 100 degrees Celsius is: {} degrees Fahrenheit".format(model.predict([100.0])))
print("These are the l0 variables: {}".format(l0.get_weights()))
print("These are the l1 variables: {}".format(l1.get_weights()))
print("These are the l2 variables: {}".format(l2.get_weights()))
# Out:
# Finished training the model
# 1/1 [==============================] - 0s 73ms/step
# [[148.23462]]
# 1/1 [==============================] - 0s 39ms/step
# Model predicts that 100 degrees Celsius is: [[148.23462]] degrees Fahrenheit
# These are the l0 variables: [array([[ 0.1648593 , -0.17650414,  0.17561918, -0.27521482]],
#       dtype=float32), array([-7.199995 ,  3.1999993, -9.6      , -6.3999963], dtype=float32)]
# These are the l1 variables: [array([[ 2.9422457 ,  2.0927389 ,  1.9698924 , -6.932624  ],
#        [ 3.3756404 ,  1.4763019 ,  0.98232996,  5.2114797 ],
#        [ 0.09486958,  0.7387807 , -0.741619  ,  3.5316396 ],
#        [-2.2459452 , -0.8133173 ,  1.5257789 , -0.8889416 ]],
#       dtype=float32), array([-40.79995   ,   0.59999955, -30.200079  ,  32.20008   ],
#       dtype=float32)]
# These are the l2 variables: [array([[-0.5522157 ],
#        [ 1.8241256 ],
#        [-0.439324  ],
#        [-0.32227904]], dtype=float32), array([44.999886], dtype=float32)]
